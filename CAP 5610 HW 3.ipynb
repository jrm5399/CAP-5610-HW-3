# %%
#import libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import svm
import math

# %%
#plot before Q2
plt.plot([-1,1],[0,0]) #margin
plt.scatter(-1, -1, color = "blue")#negative
plt.scatter(-1, 1, color = "red")  #positive
plt.scatter(1, -1, color = "red")  #positive
plt.scatter(1, 1, color = "blue")  #negative
plt.show()

# %%
#plot after Q2
plt.plot([-1,1],[0,0]) #margin
plt.scatter(-1, 1, color = "blue")#negative
plt.scatter(-1, -1, color = "red")#positive
plt.scatter(1, -1, color = "red") #positive
plt.scatter(1, 1, color = "blue") #negative

plt.show()

# %%
#Q5 A
plt.scatter(1, 1, color = "red")#positive
plt.scatter(2, 2, color = "red")#positive
plt.scatter(2, 0, color = "red")#positive

plt.scatter(0,0, color = "blue")#negative
plt.scatter(1,0, color = "blue")#negative
plt.scatter(0,1, color = "blue")#negative

plt.plot([1.75,0], [0, 3/2])

plt.show()

# %%
#Q6 A
plt.scatter(-1, 0, color = "blue")#negative
plt.scatter(0, 0, color = "red")#positive
plt.scatter(1, 0, color = "blue")#negative


plt.show()

# %%
#Q6 B

fig = plt.figure()
ax = plt.axes(projection='3d')

#3D data points
#Negative
X = math.sqrt(2)
Y = 0
Z = 1

ax.scatter3D(X, Y, Z)

#Negative
X = -math.sqrt(2)
Y = 0
Z = 1

ax.scatter3D(X, Y, Z)

#Positive
X = 0
Y = 1
Z = 0

ax.scatter3D(X, Y, Z)
